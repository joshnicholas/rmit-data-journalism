# %%
import pandas as pd
from sudulunu.helpers import pp, dumper
import random 

data = pd.read_csv('data/raw_data.csv')

# from here: 
# https://ourworldindata.org/grapher/population-with-un-projections?tab=table&time=1950..2023&country=AUS~CUW~JAM~AZE

# %%
df = data.copy()
# ['Entity', 'Code', 'Year', 'Population', 
#  'Population (Projected)']

keep = ['Australia', 'New Zealand', "Canada",'Chile','Cameroon',
        'Sri Lanka', 'Ecuador', 'Nepal', 'Mali']

df = df.loc[df['Entity'].isin(keep)]
# df = df.loc[df[]
df.dropna(subset=['Population'], inplace=True)
df = df.loc[df['Year'] == df['Year'].max()]

df = df[['Entity', 'Year', 'Population']]

df.rename(columns={'Entity': "Country"}, inplace=True)

df['Population'] = df['Population'].astype(int)

pp(df)

dumper("data", '1_populations_countries_2023', df)
# Out:
#            Country  Year  Population
# 2489     Australia  2023    26451126
# 6113      Cameroon  2023    28372690
# 6264        Canada  2023    39299098
# 7019         Chile  2023    19658833
# 9888       Ecuador  2023    17980079
# 21817         Mali  2023    23769130
# 24837        Nepal  2023    29694614
# 25290  New Zealand  2023     5172837
# 33897    Sri Lanka  2023    22971615
# ['Country', 'Year', 'Population']

# %%
df = data.copy()
# ['Entity', 'Code', 'Year', 'Population', 
#  'Population (Projected)']

keep = ['Australia']

df = df.loc[df['Entity'].isin(keep)]
# df = df.loc[df[]
df.dropna(subset=['Population'], inplace=True)
# df = df.loc[df['Year'] == df['Year'].max()]

df = df[['Entity', 'Year', 'Population']]

df.rename(columns={'Entity': "Country"}, inplace=True)

df['Population'] = df['Population'].astype(int)

pp(df)

dumper("data", '2_aus_population', df)
# Out:
#         Country  Year  Population
# 2416  Australia  1950     8176751
# 2417  Australia  1951     8418616
# 2418  Australia  1952     8630707
# 2419  Australia  1953     8816085
# 2420  Australia  1954     8999384
# ...         ...   ...         ...
# 2485  Australia  2019    25482714
# 2486  Australia  2020    25743787
# 2487  Australia  2021    25956417
# 2488  Australia  2022    26200987
# 2489  Australia  2023    26451126
#
# [74 rows x 3 columns]
# ['Country', 'Year', 'Population']

# %%
df = data.copy()
# ['Entity', 'Code', 'Year', 'Population', 
#  'Population (Projected)']

df = df.loc[df['Year'] == 2023]
df.drop(columns={'Population (Projected)'}, inplace=True)

keep = ['Australia']

# df = df.loc[df['Entity'].isin(keep)]
# # df = df.loc[df[]
# df.dropna(subset=['Population'], inplace=True)
# # df = df.loc[df['Year'] == df['Year'].max()]

# df = df[['Entity', 'Year', 'Population']]

# df.rename(columns={'Entity': "Country"}, inplace=True)

# df['Population'] = df['Population'].astype(int)
df.dropna(subset=['Code'], inplace=True)
df = df.loc[df['Code'].str.contains("UN")]

df = df.loc[~df['Entity'].isin(['Hungary', 'Tunisia'])]

pp(df)

dumper("data/other_data", 'population_un_region', df)
# Out:
#                                      Entity    Code  Year    Population
# 375                             Africa (UN)  UN_AFR  2023  1.480771e+09
# 2338                              Asia (UN)  UN_ASI  2023  4.778004e+09
# 11247                           Europe (UN)  UN_EUR  2023  7.456029e+08
# 18797  Latin America and the Caribbean (UN)  UN_LAC  2023  6.588915e+08
# 26498                 Northern America (UN)  UN_NAM  2023  3.829027e+08
# 27102                          Oceania (UN)  UN_OCE  2023  4.556279e+07
# ['Entity', 'Code', 'Year', 'Population']

# %%
df = data.copy()
# ['Entity', 'Code', 'Year', 'Population', 
#  'Population (Projected)']

df = df.loc[df['Year'] == 2023]
df.drop(columns={'Population (Projected)'}, inplace=True)

keep = ['Australia']
df.dropna(subset=['Code'], inplace=True)
df = df.loc[~df['Entity'].str.contains('(UN)')]
df = df.loc[~df['Code'].str.contains('OWID_')]


countries = df['Entity'].unique().tolist()

for i in range(1, 10):

    selection = random.choices(countries, k=5)

    zdf = df.loc[df['Entity'].isin(selection)].copy()

    dumper("data/other_data/population_random_countries", str(i), zdf)

    print(selection)
# pp(df)

# dumper("data/other_cuts", 'un_region', df)
# Out:
# ['Niger', 'Brunei', 'Saint Pierre and Miquelon', 'El Salvador', 'Antigua and Barbuda']
# ['Barbados', 'Israel', 'Malta', 'United Arab Emirates', 'Mayotte']
# ['Saint Vincent and the Grenadines', 'Mongolia', 'Slovenia', 'Bahrain', 'Bulgaria']
# ['Niger', 'El Salvador', 'Zambia', 'Wallis and Futuna', 'Comoros']
# ['Turkmenistan', 'Northern Mariana Islands', 'Mayotte', 'Iraq', 'Finland']
# ['United States Virgin Islands', 'Anguilla', 'Chad', 'Fiji', 'Maldives']
# ['Myanmar', 'Ecuador', 'United Arab Emirates', 'Reunion', 'Ecuador']
# ['Solomon Islands', 'Senegal', 'Falkland Islands', 'Tajikistan', 'Jordan']
# ['Panama', 'Haiti', 'Singapore', 'Rwanda', 'Belgium']
# /var/folders/p5/291tnlbj3vn89gqk4spr3v9h0000gn/T/ipykernel_18492/1517658831.py:10: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df = df.loc[~df['Entity'].str.contains('(UN)')]
