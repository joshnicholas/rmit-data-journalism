# %%
"Hello"
# Out:
# 'Hello'

# %%
### Simple math

# 2 - 2
# 2 * 2
# 2 / 2
# 2 % 2
# 2 + 2

# %%
### Variables

firstVariable = 2
secondVariable = 2
# Out:
# 4

# %%
### Types


# type(1)

# type('hi')
# Out:
# int

# %%
### Functions

def function(firstVariable, secondVariable):
    return firstVariable + secondVariable

# %%
### Loops

for i in range(0, 1):
    print("hi")
# Out:
# hi
