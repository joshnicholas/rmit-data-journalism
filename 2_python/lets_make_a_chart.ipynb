# %%
#### A very simple chart

data = {"Apples": 3, "Bananas": 5, "Cherries": 8}

# for fruit, count in data.items():
#     print(fruit, "*" * count)

# %%
import pandas as pd 

data = pd.read_csv('2_python/data/aus.csv')

print(data)

# data.plot(x='Year', y='Population')
